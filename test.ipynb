# %%
import pickle
import pandas as pd

# %%
model1=pickle.load(open("iris.pkl","rb"))
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model1=pickle.load(open("iris.pkl","rb"))
#
# EOFError: Ran out of input
